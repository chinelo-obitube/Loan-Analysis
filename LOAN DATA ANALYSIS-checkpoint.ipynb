# %%
import numpy as np
import pandas as pd
loan= pd.read_csv('D:/eben/loan_dataset_200k.csv')

# %%
loan.head()
# Out:
#   customer_id  customer_age customer_age_band gender customer_marital_status  \
# 0          R1            46               41+      C                Divorced
# 1          R2            56               51+      M                  Single
# 2          R3            32               31+      M                 Married
# 3          R4            34               31+      M                  Single
# 4          R5            34               31+      M                Divorced
#
#   customer_occupation_status  customer_occupation customer_educational_level  \
# 0                   Employed                  NaN                    Primary
# 1              Self-employed                  NaN                    Primary
# 2                 Unemployed                  NaN                    Primary
# 3              Self-employed                  NaN                    Primary
# 4                   Employed                  NaN                  Secondary
#
# ...

# %%
loan.shape
# Out:
# (200000, 46)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 46 columns):
# customer_id                                      200000 non-null object
# customer_age                                     200000 non-null int64
# customer_age_band                                200000 non-null object
# gender                                           200000 non-null object
# customer_marital_status                          200000 non-null object
# customer_occupation_status                       200000 non-null object
# customer_occupation                              0 non-null float64
# customer_educational_level                       200000 non-null object
# industry_or_sector                               200000 non-null object
# company_size                                     200000 non-null object
# company_turnover                                 0 non-null float64
# customer_city                                    0 non-null float64
# ...

# %%
loan.drop(['customer_occupation','company_turnover','customer_city','customer_branch','remittance_to_other_banks',                       
         'remittance_from_other_banks', 'percentage_change_in_customer_account_balance', 'customer_sentiment_score',                    
        'bank_income_from_customer', 'transaction_decline_rate'], axis=1, inplace=True)

# %%
loan[loan.cumulative_credit_amount.isnull()]
# Out:
#        customer_id  customer_age customer_age_band gender  \
# 1510         R1511            49               41+      C
# 3035         R3036            48               41+      C
# 5106         R5107             4               18-      C
# 5931         R5932             5               18-      C
# 5944         R5945             4               18-      C
# 11603       R11604             5               18-      C
# 41381       R41382             2               18-      C
# 45479       R45480            35               31+      C
# 45817       R45818             4               18-      C
# 46035       R46036            48               41+      C
# 46457       R46458             5               18-      C
# 72892       R72893            29               26+      M
# 81831       R81832             5               18-      C
# 82829       R82830            35               31+      F
# 121518     R121519             5               18-      C
# ...

# %%
loan.shape
# Out:
# (200000, 36)

# %%
loan['gender'].hist()

# %%
loan.average_monthly_tran_debit.isnull().values.any()
# Out:
# True

# %%
loan.customer_age.hist(figsize=(2,1))

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 36 columns):
# customer_id                        200000 non-null object
# customer_age                       200000 non-null int64
# customer_age_band                  200000 non-null object
# gender                             200000 non-null object
# customer_marital_status            200000 non-null object
# customer_occupation_status         200000 non-null object
# customer_educational_level         200000 non-null object
# industry_or_sector                 200000 non-null object
# company_size                       200000 non-null object
# current_loan_status                200000 non-null object
# loan_purpose                       200000 non-null object
# no_of_loans_taken_prior            200000 non-null int64
# current_interest_rate_per_annum    200000 non-null float64
# monthly_installments               200000 non-null float64
# ...

# %%
loan.customer_age.hist(alpha=0.5, bins=300,figsize=(15,10))

# %%
loan.current_loan_status.value_counts()
# Out:
# default                           50528
# paid                              50025
# running loan but bad standing     49726
# running loan but good standing    49721
# Name: current_loan_status, dtype: int64

# %%
loan.groupby('customer_occupation_status')['current_loan_status'].value_counts()
# Out:
# customer_occupation_status  current_loan_status
# Employed                    running loan but good standing    16773
#                             default                           16749
#                             paid                              16709
#                             running loan but bad standing     16540
# Self-employed               default                           16882
#                             paid                              16827
#                             running loan but bad standing     16750
#                             running loan but good standing    16439
# Unemployed                  default                           16897
#                             running loan but good standing    16509
#                             paid                              16489
#                             running loan but bad standing     16436
# Name: current_loan_status, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-bfbf7772d396> in <module>
# ----> 1 loan.groupby['customer_age'].value_counts()
#
# TypeError: 'method' object is not subscriptable

# %%
loan[loan.cumulative_credit_amount.isnull()]
# Out:
#        customer_id  customer_age customer_age_band gender  \
# 1510         R1511            49               41+      C
# 3035         R3036            48               41+      C
# 5106         R5107             4               18-      C
# 5931         R5932             5               18-      C
# 5944         R5945             4               18-      C
# 11603       R11604             5               18-      C
# 41381       R41382             2               18-      C
# 45479       R45480            35               31+      C
# 45817       R45818             4               18-      C
# 46035       R46036            48               41+      C
# 46457       R46458             5               18-      C
# 72892       R72893            29               26+      M
# 81831       R81832             5               18-      C
# 82829       R82830            35               31+      F
# 121518     R121519             5               18-      C
# ...

# %%
loan.dtypes
# Out:
# customer_id                         object
# customer_age                         int64
# customer_age_band                   object
# gender                              object
# customer_marital_status             object
# customer_occupation_status          object
# customer_educational_level          object
# industry_or_sector                  object
# company_size                        object
# current_loan_status                 object
# loan_purpose                        object
# no_of_loans_taken_prior              int64
# current_interest_rate_per_annum    float64
# monthly_installments               float64
# loan_tenure_months                   int64
# customer_income                      int64
# loan_to_income_ratio               float64
# loan_amount                          int64
# loan_account_count                   int64
# customer_segment                     int64
# cumulative_credit_volume             int64
# cumulative_credit_amount           float64
# ...

# %%
print('(number of rows, number of columns): ', loan.shape)
# Out:
# (number of rows, number of columns):  (200000, 36)

# %%
loan.isnull().sum()
# Out:
# customer_id                            0
# customer_age                           0
# customer_age_band                      0
# gender                                 0
# customer_marital_status                0
# customer_occupation_status             0
# customer_educational_level             0
# industry_or_sector                     0
# company_size                           0
# current_loan_status                    0
# loan_purpose                           0
# no_of_loans_taken_prior                0
# current_interest_rate_per_annum        0
# monthly_installments                   0
# loan_tenure_months                     0
# customer_income                        0
# loan_to_income_ratio                   0
# loan_amount                            0
# loan_account_count                     0
# customer_segment                       0
# cumulative_credit_volume               0
# cumulative_credit_amount              23
# cumulative_debit_volume                0
# ...

# %%
loan.notnull().sum()
# Out:
# customer_id                        200000
# customer_age                       200000
# customer_age_band                  200000
# gender                             200000
# customer_marital_status            200000
# customer_occupation_status         200000
# customer_educational_level         200000
# industry_or_sector                 200000
# company_size                       200000
# current_loan_status                200000
# loan_purpose                       200000
# no_of_loans_taken_prior            200000
# current_interest_rate_per_annum    200000
# monthly_installments               200000
# loan_tenure_months                 200000
# customer_income                    200000
# loan_to_income_ratio               200000
# loan_amount                        200000
# loan_account_count                 200000
# customer_segment                   200000
# cumulative_credit_volume           200000
# cumulative_credit_amount           199977
# ...

# %%
# select columns of a specific data type
object_loan = loan.select_dtypes(include=['object'])
object_loan.columns
# Out:
# Index(['customer_id', 'customer_age_band', 'gender', 'customer_marital_status',
#        'customer_occupation_status', 'customer_educational_level',
#        'industry_or_sector', 'company_size', 'current_loan_status',
#        'loan_purpose', 'balance_band', 'last_tran_date'],
#       dtype='object')

# %%
int_and_float_loan = loan.select_dtypes(include=['int', 'float'])
int_and_float_loan.columns
# Out:
# Index(['current_interest_rate_per_annum', 'monthly_installments',
#        'loan_to_income_ratio', 'cumulative_credit_amount',
#        'cumulative_debit_amount', 'average_balance',
#        'average_monthly_tran_debit', 'average_monthly_tran_credit',
#        'income_to_average_balance_ratio'],
#       dtype='object')

# %%
for i in object_loan.columns:
    print(loan[i].value_counts())
    print('-' *40)
# Out:
# R72981     1
# R167439    1
# R118955    1
# R145141    1
# R108883    1
#           ..
# R68888     1
# R183164    1
# R170148    1
# R130698    1
# R44612     1
# Name: customer_id, Length: 200000, dtype: int64
# ----------------------------------------
# 31+    73542
# 26+    37644
# 41+    29408
# 21+    21645
# 51+    18600
# 18-     6873
# 18+     6829
# 60+     5459
# Name: customer_age_band, dtype: int64
# ----------------------------------------
# M    126379
# F     67916
# C      5450
# J       255
# Name: gender, dtype: int64
# ----------------------------------------
# Widowed     50126
# Divorced    50113
# Single      49973
# Married     49788
# Name: customer_marital_status, dtype: int64
# ----------------------------------------
# Self-employed    66898
# Employed         66771
# Unemployed       66331
# Name: customer_occupation_status, dtype: int64
# ----------------------------------------
# Secondary              50396
# Primary                50049
# ...

# %%
#to check unique values in columns
for i in object_loan.columns:
    print(i)
    print(loan[i].unique())
    print('-' *40)
# Out:
# customer_id
# ['R1' 'R2' 'R3' ... 'R199998' 'R199999' 'R200000']
# ----------------------------------------
# customer_age_band
# ['41+' '51+' '31+' '18-' '26+' '21+' '60+' '18+']
# ----------------------------------------
# gender
# ['C' 'M' 'F' 'J']
# ----------------------------------------
# customer_marital_status
# ['Divorced' 'Single' 'Married' 'Widowed']
# ----------------------------------------
# customer_occupation_status
# ['Employed' 'Self-employed' 'Unemployed']
# ----------------------------------------
# customer_educational_level
# ['Primary' 'Secondary' 'No formal education' 'Tertiary']
# ----------------------------------------
# industry_or_sector
# ['Private' 'Public']
# ----------------------------------------
# company_size
# ['50 to 100' '500 to 1000' '100 to 500' 'More than 1000' 'Less than 50']
# ----------------------------------------
# current_loan_status
# ['paid' 'running loan but good standing' 'running loan but bad standing'
#  'default']
# ...

# %%
loan['customer_income'].head()
# Out:
# 0    736720
# 1     46260
# 2    734710
# 3    341430
# 4    464420
# Name: customer_income, dtype: int64

# %%
loan['customer_income']+loan['loan_amount'].isnull().any()
# Out:
# 0         736720
# 1          46260
# 2         734710
# 3         341430
# 4         464420
#            ...
# 199995    956890
# 199996    956000
# 199997    703370
# 199998    480230
# 199999    857680
# Name: customer_income, Length: 200000, dtype: int64

# %%
loan.iloc[2,5]
# Out:
# 'Unemployed'

# %%
loan.describe()
# Out:
#         customer_age  no_of_loans_taken_prior  \
# count  200000.000000            200000.000000
# mean       35.483290                 9.994695
# std        19.611176                 6.059692
# min         0.000000                 0.000000
# 25%        28.000000                 5.000000
# 50%        34.000000                10.000000
# 75%        41.000000                15.000000
# max      2018.000000                20.000000
#
#        current_interest_rate_per_annum  monthly_installments  \
# count                    200000.000000         200000.000000
# mean                          0.181392          89568.600123
# std                           0.057082          97155.001902
# min                           0.088000           2304.940000
# 25%                           0.132000          26731.380000
# 50%                           0.176000          55005.175000
# 75%                           0.231000         110849.375000
# ...

# %%
loan.corr()
# Out:
#                                  customer_age  no_of_loans_taken_prior  \
# customer_age                         1.000000                 0.001090
# no_of_loans_taken_prior              0.001090                 1.000000
# current_interest_rate_per_annum     -0.001330                -0.000965
# monthly_installments                -0.001301                -0.001133
# loan_tenure_months                   0.001161                 0.002906
# customer_income                      0.001258                 0.001503
# loan_to_income_ratio                 0.000190                -0.002724
# loan_amount                         -0.000062                -0.001960
# loan_account_count                  -0.004531                -0.003243
# customer_segment                     0.000325                -0.002579
# cumulative_credit_volume            -0.001142                 0.003105
# cumulative_credit_amount            -0.012197                -0.002759
# ...

# %%
import seaborn as sns
sns.heatmap(loan.corr());

# %%
loan.head()
# Out:
#   customer_id  customer_age customer_age_band gender customer_marital_status  \
# 0          R1            46               41+      C                Divorced
# 1          R2            56               51+      M                  Single
# 2          R3            32               31+      M                 Married
# 3          R4            34               31+      M                  Single
# 4          R5            34               31+      M                Divorced
#
#   customer_occupation_status customer_educational_level industry_or_sector  \
# 0                   Employed                    Primary            Private
# 1              Self-employed                    Primary            Private
# 2                 Unemployed                    Primary            Private
# 3              Self-employed                    Primary            Private
# 4                   Employed                  Secondary            Private
#
# ...

# %%
loan.isna().sum().sum()
# Out:
# 93575

# %%
loan.isna().sum()/(len(loan))*100
# Out:
# customer_id                         0.0000
# customer_age                        0.0000
# customer_age_band                   0.0000
# gender                              0.0000
# customer_marital_status             0.0000
# customer_occupation_status          0.0000
# customer_educational_level          0.0000
# industry_or_sector                  0.0000
# company_size                        0.0000
# current_loan_status                 0.0000
# loan_purpose                        0.0000
# no_of_loans_taken_prior             0.0000
# current_interest_rate_per_annum     0.0000
# monthly_installments                0.0000
# loan_tenure_months                  0.0000
# customer_income                     0.0000
# loan_to_income_ratio                0.0000
# loan_amount                         0.0000
# loan_account_count                  0.0000
# customer_segment                    0.0000
# cumulative_credit_volume            0.0000
# cumulative_credit_amount            0.0115
# ...

# %%
loan_df = loan.copy()

# %%
loan_df.head()
# Out:
#   customer_id  customer_age customer_age_band gender customer_marital_status  \
# 0          R1            46               41+      C                Divorced
# 1          R2            56               51+      M                  Single
# 2          R3            32               31+      M                 Married
# 3          R4            34               31+      M                  Single
# 4          R5            34               31+      M                Divorced
#
#   customer_occupation_status customer_educational_level industry_or_sector  \
# 0                   Employed                    Primary            Private
# 1              Self-employed                    Primary            Private
# 2                 Unemployed                    Primary            Private
# 3              Self-employed                    Primary            Private
# 4                   Employed                  Secondary            Private
#
# ...

# %%
loan_df.loc[:, loan_df.isnull().any()].columns
# Out:
# Index(['cumulative_credit_amount', 'cumulative_debit_amount',
#        'average_monthly_tran_debit', 'average_monthly_tran_credit'],
#       dtype='object')

# %%
loan2 = loan_df.dropna()

# %%
loan2.shape
# Out:
# (153236, 36)

# %%
loan_df = pd.DataFrame(['loan_df'])
loan_df.fillna(0)
# Out:
#          0
# 0  loan_df

# %%
loan_df.loc[:, loan_df.isnull().any()].columns
# Out:
# Index(['cumulative_credit_amount', 'cumulative_debit_amount',
#        'average_monthly_tran_debit', 'average_monthly_tran_credit'],
#       dtype='object')

# %%
loan_df.isnull().any()
# Out:
# 0    False
# dtype: bool

# %%
loan.head()
# Out:
#   customer_id  customer_age customer_age_band gender customer_marital_status  \
# 0          R1            46               41+      C                Divorced
# 1          R2            56               51+      M                  Single
# 2          R3            32               31+      M                 Married
# 3          R4            34               31+      M                  Single
# 4          R5            34               31+      M                Divorced
#
#   customer_occupation_status customer_educational_level industry_or_sector  \
# 0                   Employed                    Primary            Private
# 1              Self-employed                    Primary            Private
# 2                 Unemployed                    Primary            Private
# 3              Self-employed                    Primary            Private
# 4                   Employed                  Secondary            Private
#
# ...

# %%
loan2 = loan.copy()

# %%
loan2.dropna()
# Out:
#        customer_id  customer_age customer_age_band gender  \
# 0               R1            46               41+      C
# 1               R2            56               51+      M
# 2               R3            32               31+      M
# 3               R4            34               31+      M
# 4               R5            34               31+      M
# ...            ...           ...               ...    ...
# 199995     R199996            54               51+      F
# 199996     R199997            59               51+      M
# 199997     R199998            32               31+      M
# 199998     R199999            44               41+      M
# 199999     R200000            43               41+      F
#
#        customer_marital_status customer_occupation_status  \
# 0                     Divorced                   Employed
# 1                       Single              Self-employed
# 2                      Married                 Unemployed
# ...

# %%
loan2.
# Out:
# <bound method DataFrame.info of        customer_id  customer_age customer_age_band gender  \
# 0               R1            46               41+      C
# 1               R2            56               51+      M
# 2               R3            32               31+      M
# 3               R4            34               31+      M
# 4               R5            34               31+      M
# ...            ...           ...               ...    ...
# 199995     R199996            54               51+      F
# 199996     R199997            59               51+      M
# 199997     R199998            32               31+      M
# 199998     R199999            44               41+      M
# 199999     R200000            43               41+      F
#
#        customer_marital_status customer_occupation_status  \
# 0                     Divorced                   Employed
# 1                       Single              Self-employed
# 2                      Married                 Unemployed
# ...

# %%
loan3 = loan2.dropna()

# %%
loan3.shape
# Out:
# (153236, 36)

# %%
loan3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153236 entries, 0 to 199999
# Data columns (total 36 columns):
# customer_id                        153236 non-null object
# customer_age                       153236 non-null int64
# customer_age_band                  153236 non-null object
# gender                             153236 non-null object
# customer_marital_status            153236 non-null object
# customer_occupation_status         153236 non-null object
# customer_educational_level         153236 non-null object
# industry_or_sector                 153236 non-null object
# company_size                       153236 non-null object
# current_loan_status                153236 non-null object
# loan_purpose                       153236 non-null object
# no_of_loans_taken_prior            153236 non-null int64
# current_interest_rate_per_annum    153236 non-null float64
# monthly_installments               153236 non-null float64
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sns.set() # use Seaborn styles
loan3.pivot_table('customer_income', index='loan_amount', columns='gender').plot()
plt.ylabel('total births per year');

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sns.set() # use Seaborn styles
loan3.pivot_table('loan_amount', index='customer_age', columns='gender').plot()
plt.ylabel('total births per year');

# %%
#check outliers in age
# because max age is 2018

import seaborn as sns
sns.boxplot(data=loan3,x=loan3['customer_age'])

# %%
Q1=loan3['customer_age'].quantile(0.25)
Q3=loan3['customer_age'].quantile(0.75)
IQR=Q3-Q1
print(Q1)
print(Q3)
print(IQR)
Lower_Whisker = Q1-1.5*IQR
Upper_Whisker = Q3 + 1.5*IQR
print(Lower_Whisker, Upper_Whisker)
# Out:
# 28.0
# 41.0
# 13.0
# 8.5 60.5

# %%
loan3 = loan3[loan3['customer_age']< Upper_Whisker]
loan3.describe()
# Out:
#         customer_age  no_of_loans_taken_prior  \
# count  149137.000000            149137.000000
# mean       34.945969                 9.989882
# std        10.395604                 6.059944
# min         0.000000                 0.000000
# 25%        28.000000                 5.000000
# 50%        34.000000                10.000000
# 75%        40.000000                15.000000
# max        60.000000                20.000000
#
#        current_interest_rate_per_annum  monthly_installments  \
# count                    149137.000000         149137.000000
# mean                          0.181401          89846.393600
# std                           0.057085          97355.498213
# min                           0.088000           2304.940000
# 25%                           0.132000          26795.830000
# 50%                           0.176000          55201.800000
# 75%                           0.231000         111374.590000
# ...

# %%
import seaborn as sns
sns.boxplot(data=loan3,x=loan3['customer_age'])

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)

# %%
loan3.shape
# Out:
# (149137, 36)

# %%
loan3[['loan_amount']].mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3b07605dcf1d> in <module>
# ----> 1 loan3[['loan_amount']].mean(axis=1)
#
# NameError: name 'loan3' is not defined
